# %% [markdown]
# # Deep Learning 基礎講座 最終課題: 脳波分類 データダウンロード用
#
# - 下記の notebook を実行することで，最終課題の 脳波分類 コンペティションに利用するデータが作成されます．
# - 実行時のランタイムは CPU で問題ございません．
# - データのダウンロードと分割に 30 分ほどかかることを確認しています．
# - **スクリプト内で 1 度オリジナルのデータをダウンロードしています．サーバー負荷を考慮して可能な限り複数回の実行はお控えください．**

# %%
# omnicampus の演習環境用
# !pip install googledrivedownloader
# Out:
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.11/dist-packages (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from googledrivedownloader) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (2025.7.14)

# %%
# データのダウンロードと分割
import os
import subprocess
# !pip install googledrivedownloader
from googledrivedownloader import download_file_from_google_drive

file_id = "1swwXVBcH2RJOJwtps2D0Fl5EBJQfeGeS" if "COLAB_" in "".join(os.environ.keys()) else "1O9QhJxP3U_rLKVKnJHR4vBAjAwhXbc4Z"
download_file_from_google_drive(
    file_id=file_id,
    dest_path='./dist.zip',
    unzip=True,
)
download_file_from_google_drive(
    file_id="1cpZ0JLgzQo1wGBxtULJB35RLqIjs_gxX",
    dest_path='./split_data.sh',
)
download_file_from_google_drive(
    file_id="1eQlnnbvaMtYPJxqqffdurcrjda7YmaOs",
    dest_path='./categorization.tsv',
)
download_file_from_google_drive(
    file_id="1LfmZMCukEqK7MuOPH_fjjbZvmw-IH3mC",
    dest_path='./category_mat_manual.tsv',
)
# Out:
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.11/dist-packages (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from googledrivedownloader) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->googledrivedownloader) (2025.7.14)
# Downloading 1swwXVBcH2RJOJwtps2D0Fl5EBJQfeGeS into ./dist.zip... Done.
# Unzipping...Done.
# Downloading 1cpZ0JLgzQo1wGBxtULJB35RLqIjs_gxX into ./split_data.sh... Done.
# Downloading 1eQlnnbvaMtYPJxqqffdurcrjda7YmaOs into ./categorization.tsv... Done.
# Downloading 1LfmZMCukEqK7MuOPH_fjjbZvmw-IH3mC into ./category_mat_manual.tsv... Done.

# %%
subprocess.run(["chmod", "+x", "dist/split_data.py"])
subprocess.run(["chmod", "+x", "split_data.sh"])
output = subprocess.run(["./split_data.sh"], capture_output=True, text=True)
print(output.stdout)
# Out:
# Archive:  sub-01.zip
#    creating: data/sub-01/
#   inflating: data/sub-01/preprocessed_eeg_test.npy
#   inflating: data/sub-01/preprocessed_eeg_training.npy
# Archive:  sub-02.zip
#    creating: data/sub-02/
#   inflating: data/sub-02/preprocessed_eeg_training.npy
#   inflating: data/sub-02/preprocessed_eeg_test.npy
# Archive:  sub-03.zip
#    creating: data/sub-03/
#   inflating: data/sub-03/preprocessed_eeg_training.npy
#   inflating: data/sub-03/preprocessed_eeg_test.npy
# Archive:  sub-04.zip
#    creating: data/sub-04/
#   inflating: data/sub-04/preprocessed_eeg_test.npy
#   inflating: data/sub-04/preprocessed_eeg_training.npy
# Archive:  sub-05.zip
#    creating: data/sub-05/
#   inflating: data/sub-05/preprocessed_eeg_test.npy
#   inflating: data/sub-05/preprocessed_eeg_training.npy
# Archive:  sub-06.zip
#    creating: data/sub-06/
#   inflating: data/sub-06/preprocessed_eeg_test.npy
#   inflating: data/sub-06/preprocessed_eeg_training.npy
# Archive:  sub-07.zip
#    creating: data/sub-07/
#   inflating: data/sub-07/preprocessed_eeg_test.npy
#   inflating: data/sub-07/preprocessed_eeg_training.npy
# Archive:  sub-08.zip
#    creating: data/sub-08/
#   inflating: data/sub-08/preprocessed_eeg_test.npy
#   inflating: data/sub-08/preprocessed_eeg_training.npy
# Archive:  sub-09.zip
#    creating: data/sub-09/
#   inflating: data/sub-09/preprocessed_eeg_test.npy
#   inflating: data/sub-09/preprocessed_eeg_training.npy
# Archive:  sub-10.zip
#    creating: data/sub-10/
#   inflating: data/sub-10/preprocessed_eeg_training.npy
#   inflating: data/sub-10/preprocessed_eeg_test.npy
# Saved train labels ((118800,)) and image paths ((118800,)).
# Saved train EEG data ((118800, 17, 100)) and subject IDs ((118800,)).
# Saved val labels ((59400,)) and image paths ((59400,)).
# Saved val EEG data ((59400, 17, 100)) and subject IDs ((59400,)).
# Saved test EEG data ((59400, 17, 100)) and subject IDs ((59400,)).
#   adding: data/ (stored 0%)
#   adding: data/val/ (stored 0%)
#   adding: data/val/eeg.npy (deflated 4%)
#   adding: data/val/image_paths.txt (deflated 89%)
#   adding: data/val/labels.npy (deflated 99%)
#   adding: data/val/subject_idxs.npy (deflated 100%)
#   adding: data/test/ (stored 0%)
#   adding: data/test/eeg.npy (deflated 4%)
#   adding: data/test/subject_idxs.npy (deflated 91%)
#   adding: data/low2high_map.json (deflated 70%)
#   adding: data/train/ (stored 0%)
#   adding: data/train/eeg.npy (deflated 4%)
#   adding: data/train/image_paths.txt (deflated 94%)
#   adding: data/train/labels.npy (deflated 99%)
#   adding: data/train/subject_idxs.npy (deflated 100%)

# %%
# google drive のマウント（Colabの場合）
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# パスは保存したいディレクトリに適宜修正してください
#!cp -r data /content/drive/MyDrive/weblab/DLBasics2025/Competition/
# !cp -r data "/content/drive/MyDrive/Colab Notebooks/2025DL基礎/3_最終課題/EEG/"
